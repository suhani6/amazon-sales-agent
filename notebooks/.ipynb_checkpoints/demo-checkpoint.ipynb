# %%
# Step 1: Import the required library
import pandas as pd

# Step 2: Load the original raw CSV (update path if needed)
file_path = "../data/amazon_sales.csv"
df = pd.read_csv(file_path)

# Step 3: Normalize column names (lowercase + underscores)
df.columns = df.columns.str.strip().str.lower().str.replace(" ", "_")

# Step 4: Parse the 'order_date' column into datetime format
df['order_date'] = pd.to_datetime(df['order_date'], errors='coerce')

# Step 5: Drop rows with critical missing data
df.dropna(subset=['order_date', 'product_name', 'total_sales'], inplace=True)

# Step 6: Fill non-critical missing values (optional)
df['region'] = df['region'].fillna("Unknown")
df['quantity_sold'] = df['quantity_sold'].fillna(0)

# Step 7: Save cleaned data to a new CSV (optional for reuse)
cleaned_path = "../data/clean_amazon_sales.csv"
df.to_csv(cleaned_path, index=False)

# Step 8: Preview cleaned data
df.head()
# Out:
#                                order_id order_date  \
# 0  576ca8db-ad1a-4aa8-9c3a-89102555f200 2019-01-01
# 1  b7154d7e-f369-4a81-80b1-d36b23cc0420 2019-01-01
# 2  b2852522-fbaa-43fa-b165-bd10e0035591 2019-01-02
# 3  f14eae78-235f-4283-a2cc-6433fd861c14 2019-01-04
# 4  c3fcb6f0-a399-47eb-8903-2a354425ea75 2019-01-04
#
#                             customer_id     customer_name         region  \
# 0  48aa940a-5cb5-4103-8d89-19c10fd26aaf  Stephanie Garcia  South America
# 1  8de3545c-78e6-4962-ace5-02e37fe1ce91     Jacob Morales  South America
# 2  6ac41f61-acf6-4e46-8b70-ad00ce01c9d0      John Carroll  North America
# 3  04bb6a6a-a62a-4e79-a038-68758f215ccc   Allison Ramirez           Asia
# 4  2267ce03-37ba-446a-b279-17ecee550c6e    James Thompson  North America
#
#   product_category product_name  quantity_sold  unit_price  discount_(%)  \
# 0   Home & Kitchen        Speak              9      484.46         21.33
# ...

# %%
import sys, os
sys.path.append(os.path.abspath(".."))

from tools import analysis_tools as at

# Text insights
print("📊 Revenue by Month:\n", at.get_total_revenue_by_month())
print("\n🏆 Top 5 Products:\n", at.get_top_n_products(5))

# Chart
print("\n📈", at.plot_monthly_revenue_trend())
# Out:
# /Users/suhaniarora/Desktop/amazon_aiagent/amazon-sales-agent/tools/analysis_tools.py:10: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly_revenue = df.resample('M', on='order_date')['total_sales'].sum()
# /Users/suhaniarora/Desktop/amazon_aiagent/amazon-sales-agent/tools/analysis_tools.py:20: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly = df.resample('M', on='order_date')['total_sales'].sum()
# 📊 Revenue by Month:
#  order_date
# 2019-01-31    86731.98
# 2019-02-28    70990.77
# 2019-03-31    80847.05
# 2019-04-30    77205.55
# 2019-05-31    90999.19
#                 ...
# 2024-08-31    76419.88
# 2024-09-30    78465.06
# 2024-10-31    97348.24
# 2024-11-30    90540.09
# 2024-12-31    81869.16
# Freq: ME, Name: total_sales, Length: 72, dtype: float64
#
# 🏆 Top 5 Products:
#  product_name
# Present     24650.30
# If          19107.97
# Strategy    17599.05
# ...

# %%
import sys, os
sys.path.append(os.path.abspath(".."))

from tools import analysis_tools as at

print("💰 Average Profit by Region:\n", at.get_average_profit_by_region())
print("\n📦 Sales by Category:\n", at.get_sales_by_category())
print("\n📊", at.plot_category_distribution())
print("\n📋 Order Status Breakdown:\n", at.get_order_status_breakdown())
# Out:
# 💰 Average Profit by Region:
#  region
# South America    442.788123
# Australia        414.828485
# Europe           403.794470
# North America    401.911593
# Asia             400.718786
# Name: profit_margin, dtype: float64
#
# 📦 Sales by Category:
#  product_category
# Sports            894838.14
# Clothing          874698.53
# Toys              864701.55
# Electronics       854348.56
# Home & Kitchen    837059.82
# Books             814614.05
# Beauty            794056.99
# Name: total_sales, dtype: float64
#
# 📊 Chart saved as category_distribution.png
#
# 📋 Order Status Breakdown:
#  order_status
# Returned     1325
# Completed    1231
# Pending      1227
# Cancelled    1216
# Name: count, dtype: int64

# %%
import sys, os
sys.path.append(os.path.abspath(".."))

from agent.agent_builder import agent

# Example: Ask natural questions
response = agent.run("What is the total revenue month over month?")
print(response)

response = agent.run("Show me the top 5 products by total sales")
print(response)

response = agent.run("Can you plot the monthly revenue trend?")
print(response)
